# %%
import numpy as np 
import pandas as pd 

from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

# %%
X,y=make_classification(n_samples=150,random_state=42,n_features=2,n_classes=2,n_clusters_per_class=1,n_informative=1,n_redundant=0,hypercube=False,class_sep=30)

# %%
plt.figure(figsize=[10,6])
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
def perceptron(X,y):
    X=np.insert(X,0,1,axis=1)
    weights=np.ones(X.shape[1])
    lr=0.01

    for i in range(3000):
        j=np.random.randint(0,100)
        y_hat=step(np.dot(X[j],weights))
        weights=weights+(lr*(y[j]-y_hat)*X[j])
    return weights[0],weights[1:]

# %%
def step(z):
   return 1 if z >0 else  0

# %%
intercept_,coef_=perceptron(X,y)

# %%
intercept_
# Out:
# 1.0

# %%
coef_
# Out:
# array([1., 1.])

# %%
 m=-(coef_[0]/coef_[1])
b=-(intercept_/coef_[1])

# %%
m,b
# Out:
# (-1.0, -1.0)

# %%
x_input=np.linspace(-3,3,100)
y_input=m*x_input+b

# %%
plt.plot(x_input,y_input)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
 from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(X,y)
# Out:
# LogisticRegression()

# %%
lr.coef_
# Out:
# array([[ 0.56829772, -0.00069634]])

# %%
lr.intercept_
# Out:
# array([-3.59185416])

# %%
m=-(lr.coef_[0][0]/lr.coef_[0][1])
b=-(lr.intercept_/lr.coef_[0][1])

# %%
x_input1=np.linspace(-3,10,100)
y_input1=m*x_input1+b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.plot(x_input1,y_input1,color='black',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
